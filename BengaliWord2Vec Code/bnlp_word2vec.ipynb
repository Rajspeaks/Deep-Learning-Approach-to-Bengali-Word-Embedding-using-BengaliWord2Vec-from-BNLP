# %%
from bnlp import BengaliWord2Vec

bwv = BengaliWord2Vec()
model_path = "bnwiki_word2vec.model"
word = 'গ্রাম'
vector = bwv.generate_word_vector(model_path, word)
print(vector.shape)
print(vector)
# Out:
# (100,)
# [ 0.76293206  1.4572781  -3.7683678  -0.09726813 -1.4333438   2.8011484
#   1.9579968   1.1469388  -2.1772997   1.1281793   0.6758321   1.314071
#  -0.1841339   2.9335635   0.7044445  -4.231963    2.9034648  -2.060244
#  -1.9769906  -0.59025     2.821248   -0.6715046  -1.2261004  -1.8427833
#   0.7755015  -1.9719176   0.9116099  -1.2052754  -0.43964756  1.5836431
#  -2.9588635  -1.8440226  -1.5704885  -1.482467   -1.899114   -2.14662
#  -1.9123405   0.31349376  2.5553396   2.2489288   1.1001713  -5.982552
#   4.3503394  -0.20511855 -1.1338245   1.33564     0.24925703  0.1771953
#  -1.025408    1.7852478  -1.2566402   3.1444244  -1.5247227   1.5663935
#  -3.6793199   3.4062645   1.4110695  -1.1561761  -3.1253147  -3.712445
#   1.0562334   1.3254627  -2.1161726   0.87056375  0.5172189   3.9118512
#  -0.6090014   2.2447197  -1.9234213  -0.764041    1.8937262   0.6432401
#   1.3472961   3.9404683  -1.7026784  -0.55624783  1.2186618  -0.44829863
# ...

# %%
from bnlp import BengaliWord2Vec

bwv = BengaliWord2Vec()
model_path = "bnwiki_word2vec.model"
word = 'গ্রাম'
similar = bwv.most_similar(model_path, word, topn=10)
print(similar)
# Out:
# [('মৌজা', 0.7147208452224731), ('মহল্লা', 0.6878851652145386), ('তালুক', 0.6774986386299133), ('গ্রামের', 0.6585026383399963), ('তহসিল', 0.6413203477859497), ('পুরসভা', 0.6314382553100586), ('গ্রামে', 0.6264088749885559), ('সংগ্রামপুর', 0.6029990315437317), ('গ্রামাঞ্চল', 0.5972400307655334), ('মৌজার', 0.5972233414649963)]

# %%
from bnlp import BengaliWord2Vec

bwv = BengaliWord2Vec()
model_path = "bnwiki_word2vec.model"
word = 'গ্রাম'
similar = bwv.most_similar(model_path, word, topn=20)
print(similar)
# Out:
# [('মৌজা', 0.7147208452224731), ('মহল্লা', 0.6878851652145386), ('তালুক', 0.6774986386299133), ('গ্রামের', 0.6585026383399963), ('তহসিল', 0.6413203477859497), ('পুরসভা', 0.6314382553100586), ('গ্রামে', 0.6264088749885559), ('সংগ্রামপুর', 0.6029990315437317), ('গ্রামাঞ্চল', 0.5972400307655334), ('মৌজার', 0.5972233414649963), ('পরগনায়', 0.5926994681358337), ('দিহি', 0.5899456739425659), ('সোনামুখী', 0.5893906354904175), ('গ্রামগুলি', 0.5881837010383606), ('জামুরিয়া', 0.5829868912696838), ('গোপালপুর', 0.5829456448554993), ('গ্রামকে', 0.579800546169281), ('পরগনার', 0.5761977434158325), ('ইছাপুর', 0.5761425495147705), ('পানিহাটি', 0.5761200785636902)]

# %%
from bnlp import BengaliWord2Vec

bwv = BengaliWord2Vec()
model_path = "bnwiki_word2vec.model"
word = 'গ্রাম'
similar = bwv.most_similar(model_path, word, topn=30)
print(similar)
# Out:
# [('মৌজা', 0.7147208452224731), ('মহল্লা', 0.6878851652145386), ('তালুক', 0.6774986386299133), ('গ্রামের', 0.6585026383399963), ('তহসিল', 0.6413203477859497), ('পুরসভা', 0.6314382553100586), ('গ্রামে', 0.6264088749885559), ('সংগ্রামপুর', 0.6029990315437317), ('গ্রামাঞ্চল', 0.5972400307655334), ('মৌজার', 0.5972233414649963), ('পরগনায়', 0.5926994681358337), ('দিহি', 0.5899456739425659), ('সোনামুখী', 0.5893906354904175), ('গ্রামগুলি', 0.5881837010383606), ('জামুরিয়া', 0.5829868912696838), ('গোপালপুর', 0.5829456448554993), ('গ্রামকে', 0.579800546169281), ('পরগনার', 0.5761977434158325), ('ইছাপুর', 0.5761425495147705), ('পানিহাটি', 0.5761200785636902), ('পাড়া', 0.5750094652175903), ('পঞ্চায়েত', 0.5747630000114441), ('রাজগঞ্জ', 0.5724868774414062), ('জনপদ', 0.5701850652694702), ('পরগণায়', 0.5699931979179382), ('রামনগর', 0.5681321620941162), ('ওয়ার্ডগুলি', 0.5661376118659973), ('বাহাদুরপুর', 0.5648073554039001), ('মৌজা/মহল্লা', 0.5645679235458374), ('তালুকের', 0.5640159845352173)]

# %%
from bnlp import BengaliWord2Vec

bwv = BengaliWord2Vec()
model_path = "bnwiki_word2vec.model"
word = 'রাজদীপ'
vector = bwv.generate_word_vector(model_path, word)
print(vector.shape)
print(vector)
# Out:
# (100,)
# [ 0.09438337  0.0541383   0.0299188  -0.03058724  0.05831883 -0.0859479
#  -0.01134414  0.28785697  0.06941614 -0.11453535 -0.08283166 -0.16542813
#  -0.00463813 -0.01212751  0.23477645  0.02164581  0.01755795 -0.0859604
#  -0.08848692 -0.20550212 -0.06427374 -0.00496873  0.05589853 -0.06850056
#   0.04835609  0.06112965 -0.01631983  0.02540759  0.03645671 -0.05639996
#   0.09284903  0.06673903 -0.02833422 -0.0669582   0.00524353  0.10667641
#   0.07086897 -0.06147205  0.06598304  0.02573734 -0.08515055  0.01583076
#  -0.00283293 -0.00288297  0.1230196  -0.04102592 -0.00505259  0.04055515
#   0.04324295  0.04581095  0.11981308 -0.02132642 -0.06608751 -0.08182708
#  -0.07331154  0.01129014  0.01929871  0.07085573  0.02739715  0.16333376
#  -0.11908925  0.0100057  -0.09924243  0.00263005 -0.07527471  0.05902967
#   0.00590769 -0.09650332  0.03740502  0.07426082 -0.08000983  0.13122796
#   0.19881928  0.11588666  0.04966638  0.06304752 -0.03118058 -0.00764457
# ...

# %%
from gensim.models import Word2Vec

sentences = [["আমার", "নাম", "রাজদীপ" ], ["যাদবপুরে", "আমার", "বাড়ি"]]

model = Word2Vec(sentences, min_count=2)
print(sentences)
# Out:
# [['আমার', 'নাম', 'রাজদীপ'], ['যাদবপুরে', 'আমার', 'বাড়ি']]
